# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the Dataset

# %%
file_path = "../data/MachineLearningRating_v3.txt"
df = pd.read_csv(file_path, sep="|")

# Display the first few rows of the DataFrame
df.sample(5)
# Out:
# C:\Users\bageg\AppData\Local\Temp\ipykernel_15432\2687088125.py:2: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, sep="|")
#         UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 765429               107369      7485  2015-02-01 00:00:00            False
# 331673                84563      6772  2015-05-01 00:00:00            False
# 464977               130135      9748  2015-07-01 00:00:00            False
# 635593               150399     12614  2015-05-01 00:00:00            False
# 380254                54414      5049  2014-09-01 00:00:00            False
#
#        Citizenship        LegalType Title Language                 Bank  \
# 765429              Private company    Mr  English            ABSA Bank
# 331673                   Individual    Mr  English  First National Bank
# 464977                   Individual    Mr  English              Nedbank
# 635593                   Individual    Mr  English        Standard Bank
# 380254                   Individual    Mr  English  First National Bank
#
#             AccountType  ... ExcessSelected              CoverCategory  \
# 765429  Savings account  ...      No excess           Income Protector
# 331673  Current account  ...      No excess  Signage and Vehicle Wraps
# 464977  Current account  ...      No excess            Keys and Alarms
# 635593  Current account  ...      No excess            Keys and Alarms
# 380254  Savings account  ...      No excess                Third Party
#
#                         CoverType            CoverGroup  \
# 765429           Income Protector      Income Protector
# 331673  Signage and Vehicle Wraps  Comprehensive - Taxi
# 464977            Keys and Alarms  Comprehensive - Taxi
# 635593            Keys and Alarms  Comprehensive - Taxi
# 380254                Third Party  Comprehensive - Taxi
#
#                          Section                             Product  \
# 765429  Optional Extended Covers  Mobility Commercial Cover: Monthly
# 331673       Motor Comprehensive  Mobility Commercial Cover: Monthly
# 464977       Motor Comprehensive  Mobility Commercial Cover: Monthly
# 635593       Motor Comprehensive  Mobility Commercial Cover: Monthly
# 380254       Motor Comprehensive  Mobility Commercial Cover: Monthly
#
#        StatutoryClass StatutoryRiskType  TotalPremium TotalClaims
# 765429     Commercial     IFRS Constant      0.000000         0.0
# 331673     Commercial     IFRS Constant      0.000000         0.0
# 464977     Commercial     IFRS Constant      2.559737         0.0
# 635593     Commercial     IFRS Constant      4.415175         0.0
# 380254     Commercial     IFRS Constant      0.000000         0.0
#
# [5 rows x 52 columns]

# %%
# Data understanding
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000098 entries, 0 to 1000097
# Data columns (total 52 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   UnderwrittenCoverID       1000098 non-null  int64
#  1   PolicyID                  1000098 non-null  int64
#  2   TransactionMonth          1000098 non-null  object
#  3   IsVATRegistered           1000098 non-null  bool
#  4   Citizenship               1000098 non-null  object
#  5   LegalType                 1000098 non-null  object
#  6   Title                     1000098 non-null  object
#  7   Language                  1000098 non-null  object
#  8   Bank                      854137 non-null   object
#  9   AccountType               959866 non-null   object
#  10  MaritalStatus             991839 non-null   object
#  11  Gender                    990562 non-null   object
#  12  Country                   1000098 non-null  object
#  13  Province                  1000098 non-null  object
#  14  PostalCode                1000098 non-null  int64
#  15  MainCrestaZone            1000098 non-null  object
#  16  SubCrestaZone             1000098 non-null  object
#  17  ItemType                  1000098 non-null  object
#  18  mmcode                    999546 non-null   float64
#  19  VehicleType               999546 non-null   object
#  20  RegistrationYear          1000098 non-null  int64
#  21  make                      999546 non-null   object
#  22  Model                     999546 non-null   object
#  23  Cylinders                 999546 non-null   float64
#  24  cubiccapacity             999546 non-null   float64
#  25  kilowatts                 999546 non-null   float64
#  26  bodytype                  999546 non-null   object
#  27  NumberOfDoors             999546 non-null   float64
#  28  VehicleIntroDate          999546 non-null   object
#  29  CustomValueEstimate       220456 non-null   float64
#  30  AlarmImmobiliser          1000098 non-null  object
#  31  TrackingDevice            1000098 non-null  object
#  32  CapitalOutstanding        1000096 non-null  object
#  33  NewVehicle                846803 non-null   object
#  34  WrittenOff                358197 non-null   object
#  35  Rebuilt                   358197 non-null   object
#  36  Converted                 358197 non-null   object
#  37  CrossBorder               698 non-null      object
#  38  NumberOfVehiclesInFleet   0 non-null        float64
#  39  SumInsured                1000098 non-null  float64
#  40  TermFrequency             1000098 non-null  object
#  41  CalculatedPremiumPerTerm  1000098 non-null  float64
#  42  ExcessSelected            1000098 non-null  object
#  43  CoverCategory             1000098 non-null  object
#  44  CoverType                 1000098 non-null  object
#  45  CoverGroup                1000098 non-null  object
#  46  Section                   1000098 non-null  object
#  47  Product                   1000098 non-null  object
#  48  StatutoryClass            1000098 non-null  object
#  49  StatutoryRiskType         1000098 non-null  object
#  50  TotalPremium              1000098 non-null  float64
#  51  TotalClaims               1000098 non-null  float64
# dtypes: bool(1), float64(11), int64(4), object(36)
# memory usage: 390.1+ MB

# %%
df.describe()
# Out:
#        UnderwrittenCoverID      PolicyID    PostalCode        mmcode  \
# count         1.000098e+06  1.000098e+06  1.000098e+06  9.995460e+05
# mean          1.048175e+05  7.956682e+03  3.020601e+03  5.487770e+07
# std           6.329371e+04  5.290039e+03  2.649854e+03  1.360381e+07
# min           1.000000e+00  1.400000e+01  1.000000e+00  4.041200e+06
# 25%           5.514300e+04  4.500000e+03  8.270000e+02  6.005692e+07
# 50%           9.408300e+04  7.071000e+03  2.000000e+03  6.005842e+07
# 75%           1.391900e+05  1.107700e+04  4.180000e+03  6.005842e+07
# max           3.011750e+05  2.324600e+04  9.870000e+03  6.506535e+07
#
#        RegistrationYear      Cylinders  cubiccapacity      kilowatts  \
# count      1.000098e+06  999546.000000  999546.000000  999546.000000
# mean       2.010225e+03       4.046642    2466.743258      97.207919
# std        3.261391e+00       0.294020     442.800640      19.393256
# min        1.987000e+03       0.000000       0.000000       0.000000
# 25%        2.008000e+03       4.000000    2237.000000      75.000000
# 50%        2.011000e+03       4.000000    2694.000000     111.000000
# 75%        2.013000e+03       4.000000    2694.000000     111.000000
# max        2.015000e+03      10.000000   12880.000000     309.000000
#
#        NumberOfDoors  CustomValueEstimate  NumberOfVehiclesInFleet  \
# count  999546.000000         2.204560e+05                      0.0
# mean        4.019250         2.255311e+05                      NaN
# std         0.468314         5.645157e+05                      NaN
# min         0.000000         2.000000e+04                      NaN
# 25%         4.000000         1.350000e+05                      NaN
# 50%         4.000000         2.200000e+05                      NaN
# 75%         4.000000         2.800000e+05                      NaN
# max         6.000000         2.655000e+07                      NaN
#
#          SumInsured  CalculatedPremiumPerTerm  TotalPremium   TotalClaims
# count  1.000098e+06              1.000098e+06  1.000098e+06  1.000098e+06
# mean   6.041727e+05              1.178757e+02  6.190550e+01  6.486119e+01
# std    1.508332e+06              3.997017e+02  2.302845e+02  2.384075e+03
# min    1.000000e-02              0.000000e+00 -7.825768e+02 -1.200241e+04
# 25%    5.000000e+03              3.224800e+00  0.000000e+00  0.000000e+00
# 50%    7.500000e+03              8.436900e+00  2.178333e+00  0.000000e+00
# 75%    2.500000e+05              9.000000e+01  2.192982e+01  0.000000e+00
# max    1.263620e+07              7.442217e+04  6.528260e+04  3.930921e+05

# %%
# Checking for missing values
df.isnull().sum()
# Out:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                         145961
# AccountType                   40232
# MaritalStatus                  8259
# Gender                         9536
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                          552
# VehicleType                     552
# RegistrationYear                  0
# make                            552
# Model                           552
# Cylinders                       552
# cubiccapacity                   552
# kilowatts                       552
# bodytype                        552
# NumberOfDoors                   552
# VehicleIntroDate                552
# CustomValueEstimate          779642
# AlarmImmobiliser                  0
# TrackingDevice                    0
# CapitalOutstanding                2
# NewVehicle                   153295
# WrittenOff                   641901
# Rebuilt                      641901
# Converted                    641901
# CrossBorder                  999400
# NumberOfVehiclesInFleet     1000098
# SumInsured                        0
# TermFrequency                     0
# CalculatedPremiumPerTerm          0
# ExcessSelected                    0
# CoverCategory                     0
# CoverType                         0
# CoverGroup                        0
# Section                           0
# Product                           0
# StatutoryClass                    0
# StatutoryRiskType                 0
# TotalPremium                      0
# TotalClaims                       0
# dtype: int64

# %%
# Convert TransactionMonth to datetime
df['TransactionMonth'] = pd.to_datetime(df['TransactionMonth'])

# Fill missing values for categorical variables with mode
categorical_cols = ['Bank', 'AccountType', 'MaritalStatus', 'Gender', 'VehicleType', 'make', 'Model', 'bodytype', 'VehicleIntroDate', 'AlarmImmobiliser', 'TrackingDevice', 'CapitalOutstanding', 'NewVehicle', 'WrittenOff', 'Rebuilt', 'Converted', 'CrossBorder']
for col in categorical_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)

# Fill missing values for numerical variables with median
numerical_cols = ['mmcode', 'Cylinders', 'cubiccapacity', 'kilowatts', 'NumberOfDoors', 'CustomValueEstimate', 'NumberOfVehiclesInFleet']
for col in numerical_cols:
    df[col].fillna(df[col].median(), inplace=True)

# Fill missing values for specific columns
df['CrossBorder'].fillna("Unknown", inplace=True)
df['SumInsured'].fillna(0, inplace=True)

# Verify if missing values are handled
missing_values_after_handling = df.isnull().sum()
print("\nMissing Values After Handling:")
print(missing_values_after_handling)
# Out:
# C:\Users\bageg\AppData\Local\Temp\ipykernel_15432\908834495.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
# C:\Users\bageg\AppData\Local\Temp\ipykernel_15432\908834495.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\bageg\AppData\Local\Temp\ipykernel_15432\908834495.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\bageg\AppData\Local\Temp\ipykernel_15432\908834495.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\bageg\AppData\Local\Temp\ipykernel_15432\908834495.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\bageg\AppData\Local\Temp\ipykernel_15432\908834495.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\bageg\AppData\Local\Temp\ipykernel_15432\908834495.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# c:\Users\bageg\Desktop\10 Academy\Alpha-Care-Insurance-Solutions\venv\lib\site-packages\numpy\lib\nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\bageg\AppData\Local\Temp\ipykernel_15432\908834495.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\bageg\AppData\Local\Temp\ipykernel_15432\908834495.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['SumInsured'].fillna(0, inplace=True)
# Missing Values After Handling:
# UnderwrittenCoverID               0
# PolicyID                          0
# TransactionMonth                  0
# IsVATRegistered                   0
# Citizenship                       0
# LegalType                         0
# Title                             0
# Language                          0
# Bank                              0
# AccountType                       0
# MaritalStatus                     0
# Gender                            0
# Country                           0
# Province                          0
# PostalCode                        0
# MainCrestaZone                    0
# SubCrestaZone                     0
# ItemType                          0
# mmcode                            0
# VehicleType                       0
# RegistrationYear                  0
# make                              0
# Model                             0
# Cylinders                         0
# cubiccapacity                     0
# kilowatts                         0
# bodytype                          0
# NumberOfDoors                     0
# VehicleIntroDate                  0
# CustomValueEstimate               0
# AlarmImmobiliser                  0
# TrackingDevice                    0
# CapitalOutstanding                0
# NewVehicle                        0
# WrittenOff                        0
# Rebuilt                           0
# Converted                         0
# CrossBorder                       0
# NumberOfVehiclesInFleet     1000098
# SumInsured                        0
# TermFrequency                     0
# CalculatedPremiumPerTerm          0
# ExcessSelected                    0
# CoverCategory                     0
# CoverType                         0
# CoverGroup                        0
# Section                           0
# Product                           0
# StatutoryClass                    0
# StatutoryRiskType                 0
# TotalPremium                      0
# TotalClaims                       0
# dtype: int64

# %%
# Descriptive Statistics
descriptive_stats = df.describe()
print("\nDescriptive Statistics:")
print(descriptive_stats)

# Histograms for numerical columns
numerical_cols = ['TotalPremium', 'TotalClaims', 'RegistrationYear', 'SumInsured', 'CalculatedPremiumPerTerm']
for col in numerical_cols:
    plt.figure(figsize=(8, 6))
    sns.histplot(df[col], kde=True)
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# Descriptive Statistics:
#        UnderwrittenCoverID      PolicyID               TransactionMonth  \
# count         1.000098e+06  1.000098e+06                        1000098
# mean          1.048175e+05  7.956682e+03  2015-02-28 10:49:29.147423744
# min           1.000000e+00  1.400000e+01            2013-10-01 00:00:00
# 25%           5.514300e+04  4.500000e+03            2015-01-01 00:00:00
# 50%           9.408300e+04  7.071000e+03            2015-04-01 00:00:00
# 75%           1.391900e+05  1.107700e+04            2015-06-01 00:00:00
# max           3.011750e+05  2.324600e+04            2015-08-01 00:00:00
# std           6.329371e+04  5.290039e+03                            NaN
#
#          PostalCode        mmcode  RegistrationYear     Cylinders  \
# count  1.000098e+06  1.000098e+06      1.000098e+06  1.000098e+06
# mean   3.020601e+03  5.488056e+07      2.010225e+03  4.046616e+00
# min    1.000000e+00  4.041200e+06      1.987000e+03  0.000000e+00
# 25%    8.270000e+02  6.005692e+07      2.008000e+03  4.000000e+00
# 50%    2.000000e+03  6.005842e+07      2.011000e+03  4.000000e+00
# 75%    4.180000e+03  6.005842e+07      2.013000e+03  4.000000e+00
# max    9.870000e+03  6.506535e+07      2.015000e+03  1.000000e+01
# std    2.649854e+03  1.360059e+07      3.261391e+00  2.939410e-01
#
#        cubiccapacity     kilowatts  NumberOfDoors  CustomValueEstimate  \
# count   1.000098e+06  1.000098e+06   1.000098e+06         1.000098e+06
# mean    2.466869e+03  9.721553e+01   4.019239e+00         2.212193e+05
# min     0.000000e+00  0.000000e+00   0.000000e+00         2.000000e+04
# 25%     2.237000e+03  7.500000e+01   4.000000e+00         2.200000e+05
# 50%     2.694000e+03  1.110000e+02   4.000000e+00         2.200000e+05
# 75%     2.694000e+03  1.110000e+02   4.000000e+00         2.200000e+05
# max     1.288000e+04  3.090000e+02   6.000000e+00         2.655000e+07
# std     4.427106e+02  1.939061e+01   4.681854e-01         2.650521e+05
#
#        NumberOfVehiclesInFleet    SumInsured  CalculatedPremiumPerTerm  \
# count                      0.0  1.000098e+06              1.000098e+06
# mean                       NaN  6.041727e+05              1.178757e+02
# min                        NaN  1.000000e-02              0.000000e+00
# 25%                        NaN  5.000000e+03              3.224800e+00
# 50%                        NaN  7.500000e+03              8.436900e+00
# 75%                        NaN  2.500000e+05              9.000000e+01
# max                        NaN  1.263620e+07              7.442217e+04
# std                        NaN  1.508332e+06              3.997017e+02
#
#        TotalPremium   TotalClaims
# count  1.000098e+06  1.000098e+06
# mean   6.190550e+01  6.486119e+01
# min   -7.825768e+02 -1.200241e+04
# 25%    0.000000e+00  0.000000e+00
# 50%    2.178333e+00  0.000000e+00
# 75%    2.192982e+01  0.000000e+00
# max    6.528260e+04  3.930921e+05
# std    2.302845e+02  2.384075e+03

# %%
# Bar charts for categorical columns
categorical_cols = ['IsVATRegistered', 'Citizenship', 'LegalType', 'MaritalStatus', 'Gender', 'Country', 'Province', 'MainCrestaZone', 'SubCrestaZone', 'ItemType', 'VehicleType', 'bodytype', 'AlarmImmobiliser', 'TrackingDevice', 'NewVehicle', 'WrittenOff', 'Rebuilt', 'Converted', 'CrossBorder', 'TermFrequency', 'ExcessSelected', 'CoverCategory', 'CoverType', 'CoverGroup', 'Section', 'Product', 'StatutoryClass', 'StatutoryRiskType']
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=col, data=df, order=df[col].value_counts().index)
    plt.title(f'Bar Chart of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()

# %%
# Scatter plot and correlation matrix for TotalPremium and TotalClaims by ZipCode
plt.figure(figsize=(10, 8))
sns.scatterplot(x='TotalPremium', y='TotalClaims', hue='PostalCode', data=df)
plt.title('Scatter Plot of TotalPremium vs TotalClaims by ZipCode')
plt.xlabel('TotalPremium')
plt.ylabel('TotalClaims')
plt.legend(title='ZipCode', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

plt.figure(figsize=(10, 8))
sns.heatmap(df[['TotalPremium', 'TotalClaims', 'PostalCode']].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of TotalPremium and TotalClaims by ZipCode')
plt.show()
